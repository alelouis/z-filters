# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %%
from filters import compute_h_z, compute_b_a
from plots import show_surface, show_path, show_ir
import numpy as np

# %%
unit_circle = np.exp(1j*np.linspace(0, 2*np.pi, 1000))

# %%
# Batman
a, b = 0.7, 0.99
zeros = np.array([0.3, -b, a*np.exp(1j*np.pi/6), b*np.exp(1j*np.pi/5), 0.7*np.exp(1j*5*np.pi/6)])
poles = np.array([0.6, -a, b*np.exp(1j*np.pi/6), a*np.exp(1j*np.pi/5), 0.98*np.exp(1j*5*np.pi/6)])

show_surface((-2, 2), zeros, poles)
show_path(unit_circle, zeros, poles)
show_ir(zeros, poles)
